# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/drive/MyDrive/Copeley/clean_gss_data.csv")
display(df)
# Out:
#        year   age     sex   race  polviews  confinan  conbus  conclerg  \
# 0      1972  23.0  female  white       NaN       NaN     NaN       NaN
# 1      1972  70.0    male  white       NaN       NaN     NaN       NaN
# 2      1972  48.0  female  white       NaN       NaN     NaN       NaN
# 3      1972  27.0  female  white       NaN       NaN     NaN       NaN
# 4      1972  61.0  female  white       NaN       NaN     NaN       NaN
# ...     ...   ...     ...    ...       ...       ...     ...       ...
# 72385  2022  22.0  female  white       1.0       NaN     NaN       NaN
# 72386  2022  29.0  female  white       4.0       NaN     NaN       NaN
# 72387  2022  32.0    male  white       3.0       2.0     2.0       2.0
# 72388  2022  49.0  female  white       3.0       2.0     1.0       2.0
# 72389  2022  50.0    male  white       2.0       2.0     2.0       2.0
#
#        coneduc  confed  ...  contv  conjudge  consci  conlegis  conarmy  \
# 0          NaN     NaN  ...    NaN       NaN     NaN       NaN      NaN
# 1          NaN     NaN  ...    NaN       NaN     NaN       NaN      NaN
# 2          NaN     NaN  ...    NaN       NaN     NaN       NaN      NaN
# 3          NaN     NaN  ...    NaN       NaN     NaN       NaN      NaN
# 4          NaN     NaN  ...    NaN       NaN     NaN       NaN      NaN
# ...        ...     ...  ...    ...       ...     ...       ...      ...
# 72385      NaN     NaN  ...    NaN       NaN     NaN       NaN      NaN
# 72386      NaN     NaN  ...    NaN       NaN     NaN       NaN      NaN
# 72387      1.0     2.0  ...    2.0       3.0     1.0       1.0      1.0
# 72388      1.0     1.0  ...    2.0       2.0     1.0       2.0      1.0
# 72389      2.0     2.0  ...    3.0       3.0     1.0       2.0      1.0
#
#        conpharvac  conpharvacy  confedvac  confedvacy  conhlth
# 0             NaN          NaN        NaN         NaN      NaN
# 1             NaN          NaN        NaN         NaN      NaN
# 2             NaN          NaN        NaN         NaN      NaN
# 3             NaN          NaN        NaN         NaN      NaN
# 4             NaN          NaN        NaN         NaN      NaN
# ...           ...          ...        ...         ...      ...
# 72385         NaN          NaN        NaN         NaN      NaN
# 72386         NaN          NaN        NaN         NaN      NaN
# 72387         NaN          NaN        NaN         NaN      NaN
# 72388         NaN          1.0        NaN         1.0      2.0
# 72389         NaN          1.0        NaN         1.0      NaN
#
# [72390 rows x 23 columns]

# %%
#Making a histogram for conhlth
var = "conhlth"
bin_edges = np.arange(1, 4, 0.5) #sets bin weidth for histogram
plt.hist(df[var], alpha = alpha)
plt.xlabel("Confidence Level of Health Care")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
#histogram for Medicine (Q2)

var = "conmedic"
bin_edges = np.arange(1, 4, 0.5) #sets bin weidth for histogram
plt.hist(df[var6], bin_edges, alpha = alpha)
plt.xlabel("Confidence Level of Medicine")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
#making a scatter plot of conhlth (Q3)

var = "conhlth"
cat2 = "race"

sns.kdeplot(data=df, x=var, hue = cat2)
plt.title("Confidence in Health System Grouped by Race")
plt.xlabel("Confidence in Health System")
# Out:
# Text(0.5, 0, 'Confidence in Health System')

# %%
#histogram for general confidence in conhlth (Q1)
var = "conhlth"
cat2 = "race"

sns.boxplot(data=df, x=var)
plt.xlabel("Confidence in Health System")
print(df[var].describe())
# Out:
# count    1147.000000
# mean        3.055798
# std         0.958306
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000
# Name: conhlth, dtype: float64

# %%
#boxplot for conhlth grouped by race (Q3)
var = "conhlth"
cat2 = "race"

df.boxplot(column = var, by = cat2)
plt.title("Confidence in Health Care System Grouped by Race")
plt.ylabel("Confidence Level")
# Out:
# Text(0, 0.5, 'Confidence Level')

# %%
#density plot for conhlth and grouped by sex (Q5)
var = "conhlth"
cat2 = "sex"

sns.kdeplot(data=df, x=var, hue = cat2)
plt.title("Confidence in Health System Grouped by Sex")
plt.xlabel("Confidence in Health System")
# Out:
# Text(0.5, 0, 'Confidence in Health System')

# %%
#boxplot for conhlth grouped by sex (Q5)
var = "conhlth"
cat2 = "sex"

df.boxplot(column = var, by = cat2)
plt.title("Confidence in Health Care System Grouped by Sex")
plt.ylabel("Confidence Level")
# Out:
# Text(0, 0.5, 'Confidence Level')

# %%
#line graph (Q9)
var1 = "consci"
var2 = "conmedic"
sns.lineplot(data=df, x="year", y=var1, label="Confidence in Science")
sns.lineplot(data=df, x="year", y=var2, label="Confidence in Medicine")
plt.ylabel("confidence")
# Out:
# Text(0, 0.5, 'confidence')

# %%
var1 = "consci"
var2 = "conmedic"
var3 = "conlegis"
var4 = "conclerg"
var5 = "coneduc"

graph = sns.lineplot(data=df, x="year", y=var1, label="Confidence in Science")
sns.lineplot(data=df, x="year", y=var2, label="Confidence in Medicine")
sns.lineplot(data=df, x="year", y=var3, label="Confidence in Congress")
sns.lineplot(data=df, x="year", y=var4, label="Confidence in Religion")
sns.lineplot(data=df, x="year", y=var5, label="Confidence in Education")

plt.ylabel("confidence")
# Out:
# Text(0, 0.5, 'confidence')
